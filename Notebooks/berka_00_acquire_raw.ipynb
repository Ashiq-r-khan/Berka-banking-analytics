# %%
from google.colab import drive
drive.mount('/content/drive')

import pathlib, urllib.request
RAW = pathlib.Path('/content/drive/MyDrive/berka-banking-analytics/Data/raw')
BASE = 'https://raw.githubusercontent.com/jlacko/berka-dataset/master/'

for t in ['account','card','client','disp','district','loan','order','trans']:
    urllib.request.urlretrieve(f'{BASE}{t}.asc', RAW / f'{t}.asc')
    print(t, (RAW / f'{t}.asc').stat().st_size)
# Out:
# Mounted at /content/drive
# account 155356
# card 31588
# client 94820
# disp 129716
# district 6574
# loan 27037
# order 273800
# trans 69406578
